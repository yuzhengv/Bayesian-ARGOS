# %%
library(plot3D)
library(tidyr)
library(tidyverse)
library(scales)
library(latex2exp)
library(cowplot)
library(ggh4x)
library(ggpubr)
library(patchwork)

library(scales)
library(reticulate)
library(RColorBrewer)
library(stringr)
library(dplyr)
# Out:
# Warning message in fun(libname, pkgname):
# “couldn't connect to display "/private/tmp/com.apple.launchd.gw7x1NnjBg/org.xquartz:0"”
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ purrr     1.0.2
# ✔ forcats   1.0.0     ✔ readr     2.1.5
# ✔ ggplot2   3.5.1     ✔ stringr   1.5.1
# ✔ lubridate 1.9.4     ✔ tibble    3.2.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ purrr::%||%()   masks base::%||%()
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: ‘scales’
#
#
# The following object is masked from ‘package:purrr’:
#
#     discard
#
#
# The following object is masked from ‘package:readr’:
#
#     col_factor
#
#
#
# Attaching package: ‘cowplot’
#
#
# The following object is masked from ‘package:lubridate’:
#
#     stamp
#
#
#
# ...

# %%
setwd(dirname(dirname(dirname(getwd()))))
pysindy_path <- file.path(getwd(), "Pysindy")

# %%
source(
    "./Pysindy/utils/utils-functions-for-plots/pysindy_functions_for_analysis_of_identified_terms_vary_snr.R"
)
# Out:
# Attaching package: ‘gridExtra’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
#
#
# ...
# circlize version 0.4.16
# CRAN page: https://cran.r-project.org/package=circlize
# Github page: https://github.com/jokergoo/circlize
# Documentation: https://jokergoo.github.io/circlize_book/book/
#
# If you use it in published research, please cite:
# Gu, Z. circlize implements and enhances circular visualization
#   in R. Bioinformatics 2014.
#
# This message can be suppressed by:
#   suppressPackageStartupMessages(library(circlize))
# ...

# %%
total_results_summary_df <- enhance_total_results_summary_df_py(
    root_path = pysindy_path,
    experiment_name_list = list("pysindy"),
    method_list = list("pysindy"),
    num_init = 100,
    dynamical_system_name = "aizawa",
    exp_n = FALSE,
    typical_pattern = "n5000"
)

# total_results_summary_df[total_results_summary_df$function_id == 2, ]

# Optimized figure size and margins for clearer visualization
nbfigsize(12, 12, 300) # Increased from 15x15 for better clarity
old_par <- par(no.readonly = TRUE)
on.exit(par(old_par), add = TRUE)
par(mar = c(0, 0, 0, 0), oma = c(0, 0, 0, 0), xaxs = "r", yaxs = "r")
par(plt = c(0, 1, 0, 1))


plot_freq_of_identified_terms_circular_equations_as_sectors_refined_2(
    total_results_summary_df = total_results_summary_df,
    function_number = 3,
    true_terms_1 = c("$x_{2}$", "$x_{1}$", "$x_{1}x_{3}$"),
    true_terms_2 = c("$x_{1}$", "$x_{2}$", "$x_{2}x_{3}$"),
    true_terms_3 = c(
        "$x_{3}$",
        "$C$",
        "$x_{1}^{3}x_{3}$",
        "$x_{3}^{3}$",
        "$x_{1}^{2}x_{3}$",
        "$x_{1}^{2}$",
        "$x_{2}^{2}x_{3}$",
        "$x_{2}^{2}$"
    ),
    method_name = "pysindy",
    snr_list = list(20, 25, 37, 50, 60, 61),
    plot_title = NULL,
    min_freq_for_label = 0.0,
    adjustment_for_labels = 0.4,
    use_special_positioning = FALSE,
    snr_order = "ascending"
)
# Out:
# [1] "/Users/yuzhengzhang/Documents-Local/Code-Local/Bayesian-ARGOS/Pysindy/exp/aizawa/results/aizawa_snr1_snr61_se100_n5000.RData"
# [1] 1
# [1] 100
# [1] 2
# [1] 100
# [1] 3
# [1] 100
# [1] 4
# [1] 100
# [1] 5
# [1] 100
# [1] 6
# [1] 100
# [1] 7
# [1] 100
# [1] 8
# [1] 100
# [1] 9
# [1] 100
# [1] 10
# [1] 100
# [1] 11
# [1] 100
# [1] 12
# [1] 100
# [1] 13
# [1] 100
# [1] 14
# [1] 100
# [1] 15
# [1] 100
# [1] 16
# [1] 100
# [1] 17
# [1] 100
# [1] 18
# [1] 100
# [1] 19
# [1] 100
# [1] 20
# [1] 100
# [1] 21
# [1] 100
# [1] 22
# [1] 100
# [1] 23
# [1] 100
# [1] 24
# [1] 100
# [1] 25
# [1] 100
# [1] 26
# [1] 100
# [1] 27
# [1] 100
# [1] 28
# [1] 100
# [1] 29
# [1] 100
# [1] 30
# [1] 100
# [1] 31
# [1] 100
# [1] 32
# [1] 100
# [1] 33
# [1] 100
# [1] 34
# [1] 100
# [1] 35
# [1] 100
# [1] 36
# [1] 100
# [1] 37
# [1] 100
# [1] 38
# [1] 100
# [1] 39
# [1] 100
# [1] 40
# [1] 100
# [1] 41
# [1] 100
# [1] 42
# [1] 100
# [1] 43
# [1] 100
# [1] 44
# [1] 100
# [1] 45
# [1] 100
# [1] 46
# [1] 100
# ...

# %%
output_dir <- "./ResultsAnalysis/Organise-Plots/identified-terms-plots/imgs"
output_path <- paste0(output_dir, "/aizawa_circular_plot_snr_sindy.png")

png(output_path, width = 12, height = 12, units = "in", res = 300)
par(mar = c(0, 0, 0, 0), oma = c(0, 0, 0, 0), xaxs = "r", yaxs = "r")
par(plt = c(0, 1, 0, 1))

plot_freq_of_identified_terms_circular_equations_as_sectors_refined_2(
    total_results_summary_df = total_results_summary_df,
    function_number = 3,
    true_terms_1 = c("$x_{2}$", "$x_{1}$", "$x_{1}x_{3}$"),
    true_terms_2 = c("$x_{1}$", "$x_{2}$", "$x_{2}x_{3}$"),
    true_terms_3 = c(
        "$x_{3}$",
        "$C$",
        "$x_{1}^{3}x_{3}$",
        "$x_{3}^{3}$",
        "$x_{1}^{2}x_{3}$",
        "$x_{1}^{2}$",
        "$x_{2}^{2}x_{3}$",
        "$x_{2}^{2}$"
    ),
    method_name = "pysindy",
    snr_list = list(20, 25, 37, 50, 60, 61),
    plot_title = NULL,
    min_freq_for_label = 0.0,
    adjustment_for_labels = 0.4,
    use_special_positioning = FALSE,
    snr_order = "ascending"
)

dev.off()

print(paste("Circular plot saved to:", output_path))
# Out:
# Using custom snr values: 20, 25, 37, 50, 60, 61
# Warning message in plot_freq_of_identified_terms_circular_equations_as_sectors_refined_2(total_results_summary_df = total_results_summary_df, :
# “Reducing track height to 0.148 due to space constraints with 6 snr values”
# Using snr-specific colors for bars across all sectors
# Note: 1 point is out of plotting region in sector 'Eq1', track '2'.
#
# Note: 1 point is out of plotting region in sector 'Eq1', track '2'.
# pdf
#   2
# [1] "Circular plot saved to: ./ResultsAnalysis/Organise-Plots/identified-terms-plots/imgs/aizawa_circular_plot_snr_sindy.png"
