# %%
library(plot3D)
library(tidyr)
library(tidyverse)
library(scales)
library(latex2exp)
library(cowplot)
library(ggh4x)
library(ggpubr)
library(patchwork)

library(scales)
library(reticulate)
library(RColorBrewer)
library(stringr)
library(dplyr)
# Out:
# Warning message in fun(libname, pkgname):
# “couldn't connect to display "/private/tmp/com.apple.launchd.gw7x1NnjBg/org.xquartz:0"”
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ purrr     1.0.2
# ✔ forcats   1.0.0     ✔ readr     2.1.5
# ✔ ggplot2   3.5.1     ✔ stringr   1.5.1
# ✔ lubridate 1.9.4     ✔ tibble    3.2.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ purrr::%||%()   masks base::%||%()
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: ‘scales’
#
#
# The following object is masked from ‘package:purrr’:
#
#     discard
#
#
# The following object is masked from ‘package:readr’:
#
#     col_factor
#
#
#
# Attaching package: ‘cowplot’
#
#
# The following object is masked from ‘package:lubridate’:
#
#     stamp
#
#
#
# Attaching package: ‘ggpubr’
#
#
# The following object is masked from ‘package:cowplot’:
#
#     get_legend
#
#
#
# Attaching package: ‘patchwork’
#
#
# The following object is masked from ‘package:cowplot’:
#
#     align_plots

# %%
setwd(dirname(dirname(dirname(getwd()))))
root_path <- getwd()

# %%
source(
    "./MethodsEvaluation/evaluation-functions-for-plots/functions_for_analysis_of_identified_terms_vary_n_enhanced.R"
)
# Out:
# Attaching package: ‘gridExtra’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
#
#
# ========================================
# circlize version 0.4.16
# CRAN page: https://cran.r-project.org/package=circlize
# Github page: https://github.com/jokergoo/circlize
# Documentation: https://jokergoo.github.io/circlize_book/book/
#
# If you use it in published research, please cite:
# Gu, Z. circlize implements and enhances circular visualization
#   in R. Bioinformatics 2014.
#
# This message can be suppressed by:
#   suppressPackageStartupMessages(library(circlize))
# ========================================

# %%
total_results_summary_df <- enhance_total_results_summary_df(
    root_path = root_path,
    experiment_name_list = list("bayesian-alasso-ro"),
    method_list = list("bayesian-alasso-ro"),
    function_number = 3,
    num_init = 100,
    dynamical_system_name = "lorenz",
    exp_n = TRUE,
    typical_pattern = "snr49"
)

# Optimized figure size and margins for clearer visualization
nbfigsize(12, 12, 300) # Increased from 15x15 for better clarity

old_par <- par(no.readonly = TRUE)
on.exit(par(old_par), add = TRUE)
par(mar = c(0, 0, 0, 0), oma = c(0, 0, 0, 0), xaxs = "r", yaxs = "r")
par(plt = c(0, 1, 0, 1))

plot_freq_of_identified_terms_circular_equations_as_sectors_refined(
    total_results_summary_df = total_results_summary_df,
    function_number = 3,
    true_terms_1 <- c("$x_{1}$", "$x_{2}$"),
    true_terms_2 <- c("$x_{1}$", "$x_{1}x_{3}$", "$x_{2}$"),
    true_terms_3 <- c("$x_{1}x_{2}$", "$x_{3}$"),
    method_name = "bayesian-alasso-ro",
    eta_list = list(2.8, 3, 3.5, 4, 5),
    min_freq_for_label = 0.0,
    adjustment_for_labels = 0.95,
    use_special_positioning = FALSE,
    eta_order = "ascending",
)
# Out:
# [1] "/Users/yuzhengzhang/Documents-Local/Code-Local/Bayesian-ARGOS/Experiments/bayesian-alasso-ro/lorenz/results/lorenz_1_e2_e3_se100_snr49.RData"
# [2] "/Users/yuzhengzhang/Documents-Local/Code-Local/Bayesian-ARGOS/Experiments/bayesian-alasso-ro/lorenz/results/lorenz_1_e3_e4_se100_snr49.RData"
# [3] "/Users/yuzhengzhang/Documents-Local/Code-Local/Bayesian-ARGOS/Experiments/bayesian-alasso-ro/lorenz/results/lorenz_1_e4_e5_se100_snr49.RData"
# [1] "/Users/yuzhengzhang/Documents-Local/Code-Local/Bayesian-ARGOS/Experiments/bayesian-alasso-ro/lorenz/results/lorenz_2_e2_e3_se100_snr49.RData"
# [2] "/Users/yuzhengzhang/Documents-Local/Code-Local/Bayesian-ARGOS/Experiments/bayesian-alasso-ro/lorenz/results/lorenz_2_e3_e4_se100_snr49.RData"
# [3] "/Users/yuzhengzhang/Documents-Local/Code-Local/Bayesian-ARGOS/Experiments/bayesian-alasso-ro/lorenz/results/lorenz
# Note: 1 point is out of plotting region in sector 'Eq1', track '2'.
#
# Note: 1 point is out of plotting region in sector 'Eq1', track '2'.
# Plot with title “Identified Terms Frequency by Equations”

# %%
total_results_summary_df <- enhance_total_results_summary_df(
    root_path = root_path,
    experiment_name_list = list("argos-alasso"),
    method_list = list("argos-alasso"),
    function_number = 3,
    num_init = 100,
    dynamical_system_name = "lorenz",
    exp_n = TRUE,
    typical_pattern = "snr49"
)

nbfigsize(12, 12, 300) # Increased from 15x15 for better clarity
old_par <- par(no.readonly = TRUE)
on.exit(par(old_par), add = TRUE)
par(mar = c(0, 0, 0, 0), oma = c(0, 0, 0, 0), xaxs = "r", yaxs = "r")
par(plt = c(0, 1, 0, 1))

plot_freq_of_identified_terms_circular_equations_as_sectors_refined(
    total_results_summary_df = total_results_summary_df,
    function_number = 3,
    true_terms_1 <- c("$x_{1}$", "$x_{2}$"),
    true_terms_2 <- c("$x_{1}$", "$x_{1}x_{3}$", "$x_{2}$"),
    true_terms_3 <- c("$x_{1}x_{2}$", "$x_{3}$"),
    method_name = "argos-alasso",
    eta_list = list(2.8, 3, 3.5, 4, 5),
    min_freq_for_label = 0.0,
    adjustment_for_labels = 0.95,
    use_special_positioning = FALSE,
    eta_order = "ascending",
)
# Out:
# [1] "/Users/yuzhengzhang/Documents-Local/Code-Local/Bayesian-ARGOS/Experiments/argos-alasso/lorenz/results/lorenz_1_e2_e3_bo2000_se100_alasso_ridge_snr49.RData"
# [2] "/Users/yuzhengzhang/Documents-Local/Code-Local/Bayesian-ARGOS/Experiments/argos-alasso/lorenz/results/lorenz_1_e3_e4_bo2000_se100_alasso_ridge_snr49.RData"
# [3] "/Users/yuzhengzhang/Documents-Local/Code-Local/Bayesian-ARGOS/Experiments/argos-alasso/lorenz/results/lorenz_1_e4_e5_bo2000_se100_alasso_ridge_snr49.RData"
# [1] "/Users/yuzhengzhang/Documents-Local/Code-Local/Bayesian-ARGOS/Experiments/argos-alasso/lorenz/results/lorenz_2_e2_e3_bo2000_se100_alasso_ridge_snr49.RData"
# [2] "/Users/yuzhengzhang/Documents-Local/Code-Local/Bayesian-ARGOS/Experiments/argos-alasso/lorenz/results/lorenz_2_e3_e4_bo2000_se100_alasso_ridge_snr49.RData"
# [3] "/Users/yuzhengzhang/Documents-Local/Code-Local/Bayesian-ARGOS/Experiments/argos-alasso/lorenz/results/lorenz_2_e4_e5_bo2000_se100_alasso_ridge_snr49.RData"
# [1] "/Users/yuzhengzhang/Documents-Local/Code-Local/Bayesian-ARGOS/Experiments/argos-alasso/lorenz/results/lorenz_3_e2_e3_bo2000_se100_alasso_ridge_snr49.RData"
# [2] "/Users/yuzhengzhang/Documents-Local/Code-Local/Bayesian-ARGOS/Experiments/argos-alasso/lorenz/results/lorenz_3_e3_e4_bo2000_se100_alasso_ridge_snr49.RData"
# [3] "/Users/yuzhengzhang/Documents-Local/Code-Local/Bayesian-ARGOS/Experiments/argos-alasso/lorenz/results/lorenz_3_e4_e5_bo2000_se100_alasso_ridge_snr49.RData"
# [1] 1
# [1] 100
# [1] 2
# [1] 100
# [1] 3
# [1] 100
# [1] 4
# [1] 100
# [1] 5
# [1] 100
# [1] 6
# [1] 100
# [1] 7
# [1] 100
# [1] 8
# [1] 100
# [1] 9
# [1] 100
# [1] 10
# [1] 100
# [1] 11
# [1] 100
# [1] 12
# [1] 100
# [1] 13
# [1] 100
# [1] 14
# [1] 100
# [1] 15
# [1] 100
# [1] 16
# [1] 100
# [1] 17
# [1] 100
# [1] 18
# [1] 100
# [1] 19
# [1] 100
# [1] 20
# [1] 100
# [1] 21
# [1] 100
# [1] 22
# [1] 100
# [1] 23
# [1] 100
# [1] 24
# [1] 100
# [1] 25
# [1] 100
# [1] 26
# [1] 100
# [1] 27
# [1] 100
# [1] 28
# [1] 100
# [1] 29
# [1] 100
# [1] 30
# [1] 100
# [1] 31
# [1] 100
# [1] 1
# [1] 100
# [1] 2
# [1] 100
# [1] 3
# [1] 100
# [1] 4
# [1] 100
# [1] 5
# [1] 100
# [1] 6
# [1] 100
# [1] 7
# [1] 100
# [1] 8
# [1] 100
# [1] 9
# [1] 100
# [1] 10
# [1] 100
# [1] 11
# [1] 100
# [1] 12
# [1] 100
# [1] 13
# [1] 100
# [1] 14
# [1] 100
# [1] 15
# [1] 100
# [1] 16
# [1] 100
# [1] 17
# [1] 100
# [1] 18
# [1] 100
# [1] 19
# [1] 100
# [1] 20
# [1] 100
# [1] 21
# [1] 100
# [1] 22
# [1] 100
# [1] 23
# [1] 100
# [1] 24
# [1] 100
# [1] 25
# [1] 100
# [1] 26
# [1] 100
# [1] 27
# [1] 100
# [1] 28
# [1] 100
# [1] 29
# [1] 100
# [1] 30
# [1] 100
# [1] 31
# [1] 100
# [1] 1
# [1] 100
# [1] 2
# [1] 100
# [1] 3
# [1] 100
# [1] 4
# [1] 100
# [1] 5
# [1] 100
# [1] 6
# [1] 100
# [1] 7
# [1] 100
# [1] 8
# [1] 100
# [1] 9
# [1] 100
# [1] 10
# [1] 100
# [1] 11
# [1] 100
# [1] 12
# [1] 100
# [1] 13
# [1] 100
# [1] 14
# [1] 100
# [1] 15
# [1] 100
# [1] 16
# [1] 100
# [1] 17
# [1] 100
# [1] 18
# [1] 100
# [1] 19
# [1] 100
# [1] 20
# [1] 100
# [1] 21
# [1] 100
# [1] 22
# [1] 100
# [1] 23
# [1] 100
# [1] 24
# [1] 100
# [1] 25
# [1] 100
# [1] 26
# [1] 100
# [1] 27
# [1] 100
# [1] 28
# [1] 100
# [1] 29
# [1] 100
# [1] 30
# [1] 100
# [1] 31
# [1] 100
# Using custom eta values: 2.8, 3, 3.5, 4, 5
# Warning message in plot_freq_of_identified_terms_circular_equations_as_sectors_refined(total_results_summary_df = total_results_summary_df, :
# “Reducing track height to 0.178 due to space constraints with 5 eta values”
# Using eta-specific colors for bars across all sectors
# Note: 1 point is out of plotting region in sector 'Eq1', track '2'.
#
# Note: 1 point is out of plotting region in sector 'Eq1', track '2'.
# Plot with title “Identified Terms Frequency by Equations”

# %%
total_results_summary_df <- enhance_total_results_summary_df(
    root_path = root_path,
    experiment_name_list = list("bayesian-alasso-ro"),
    method_list = list("bayesian-alasso-ro"),
    function_number = 3,
    num_init = 100,
    dynamical_system_name = "lorenz",
    exp_n = TRUE,
    typical_pattern = "snr49"
)

output_dir <- "./ResultsAnalysis/Organise-Plots/identified-terms-plots/imgs"
output_path <- paste0(output_dir, "/lorenz_circular_plot_n_ba.png")

png(output_path, width = 12, height = 12, units = "in", res = 300)
par(mar = c(0, 0, 0, 0), oma = c(0, 0, 0, 0), xaxs = "r", yaxs = "r")
par(plt = c(0, 1, 0, 1))

plot_freq_of_identified_terms_circular_equations_as_sectors_refined(
    total_results_summary_df = total_results_summary_df,
    function_number = 3,
    true_terms_1 <- c("$x_{1}$", "$x_{2}$"),
    true_terms_2 <- c("$x_{1}$", "$x_{1}x_{3}$", "$x_{2}$"),
    true_terms_3 <- c("$x_{1}x_{2}$", "$x_{3}$"),
    method_name = "bayesian-alasso-ro",
    eta_list = list(2.8, 3, 3.5, 4, 5),
    min_freq_for_label = 0.0,
    adjustment_for_labels = 0.95,
    use_special_positioning = FALSE,
    eta_order = "ascending",
)

dev.off()
print(paste("Circular plot saved to:", output_path))
# Out:
# [1] "/Users/yuzhengzhang/Documents-Local/Code-Local/Bayesian-ARGOS/Experiments/bayesian-alasso-ro/lorenz/results/lorenz
# [1] 100
# [1] 21
# [1] 100
# [1] 22
# [1] 100
# [1] 23
# [1] 100
# [1] 24
# [1] 100
# [1] 25
# [1] 100
# [1] 26
# [1] 100
# [1] 27
# [1] 100
# [1] 28
# [1] 100
# [1] 29
# [1] 100
# [1] 30
# [1] 100
# [1] 31
# [1] 100
# Using custom eta values: 2.8, 3, 3.5, 4, 5
# Warning message in plot_freq_of_identified_terms_circular_equations_as_sectors_refined(total_results_summary_df = total_results_summary_df, :
# “Reducing track height to 0.178 due to space constraints with 5 eta values”
# Using eta-specific colors for bars across all sectors
# Note: 1 point is out of plotting region in sector 'Eq1', track '2'.
#
# Note: 1 point is out of plotting region in sector 'Eq1', track '2'.
# pdf
#   2
# [1] "Circular plot saved to: ./ResultsAnalysis/Organise-Plots/identified-terms-plots/imgs/lorenz_circular_plot_n_ba.png"

# %%
total_results_summary_df <- enhance_total_results_summary_df(
    root_path = root_path,
    experiment_name_list = list("argos-alasso"),
    method_list = list("argos-alasso"),
    function_number = 3,
    num_init = 100,
    dynamical_system_name = "lorenz",
    exp_n = TRUE,
    typical_pattern = "snr49"
)

output_dir <- "./ResultsAnalysis/Organise-Plots/identified-terms-plots/imgs"
output_path <- paste0(output_dir, "/lorenz_circular_plot_n_argos.png")

png(output_path, width = 12, height = 12, units = "in", res = 300)
par(mar = c(0, 0, 0, 0), oma = c(0, 0, 0, 0), xaxs = "r", yaxs = "r")
par(plt = c(0, 1, 0, 1))

plot_freq_of_identified_terms_circular_equations_as_sectors_refined(
    total_results_summary_df = total_results_summary_df,
    function_number = 3,
    true_terms_1 <- c("$x_{1}$", "$x_{2}$"),
    true_terms_2 <- c("$x_{1}$", "$x_{1}x_{3}$", "$x_{2}$"),
    true_terms_3 <- c("$x_{1}x_{2}$", "$x_{3}$"),
    method_name = "argos-alasso",
    eta_list = list(2.8, 3, 3.5, 4, 5),
    min_freq_for_label = 0.0,
    adjustment_for_labels = 0.95,
    use_special_positioning = FALSE,
    eta_order = "ascending",
)

dev.off()
print(paste("Circular plot saved to:", output_path))
# Out:
# [1] "/Users/yuzhengzhang/Documents-Local/Code-Local/Bayesian-ARGOS/Experiments/argos-alasso/lorenz/results/lorenz_1_e2_e3_bo2000_se100_alasso_ridge_snr49.RData"
# [2] "/Users/yuzhengzhang/Documents-Local/Code-Local/Bayesian-ARGOS/Experiments/argos-alasso/lorenz/results/lorenz_1_e3_e4_bo2000_se100_alasso_ridge_snr49.RData"
# [3] "/Users/yuzhengzhang/Documents-Local/Code-Local/Bayesian-ARGOS/Experiments/argos-alasso/lorenz/results/lorenz_1_e4_e5_bo2000_se100_alasso_ridge_snr49.RData"
# [1] "/Users/yuzhengzhang/Documents-Local/Code-Local/Bayesian-ARGOS/Experiments/argos-alasso/lorenz/results/lorenz_2_e2_e3_bo2000_se100_alasso_ridge_snr49.RData"
# [2] "/Users/yuzhengzhang/Documents-Local/Code-Local/Bayesian-ARGOS/Experiments/argos-alasso/lorenz/results/lorenz_2_e3_e4_bo2000_se100_alasso_ridge_snr49.RData"
# [3] "/Users/yuzhengzhang/Documents-Local/Code-Local/Bayesian-ARGOS/Experiments/argos-alasso/lorenz/results/lorenz_2_e4_e5_bo2000_se100_alasso_ridge_snr49.RData"
# [1] "/Users/yuzhengzhang/Documents-Local/Code-Local/Bayesian-ARGOS/Experiments/argos-alasso/lorenz/results/lorenz_3_e2_e3_bo2000_se100_alasso_ridge_snr49.RData"
# [2] "/Users/yuzhengzhang/Documents-Local/Code-Local/Bayesian-ARGOS/Experiments/argos-alasso/lorenz/results/lorenz_3_e3_e4_bo2000_se100_alasso_ridge_snr49.RData"
# [3] "/Users/yuzhengzhang/Documents-Local/Code-Local/Bayesian-ARGOS/Experiments/argos-alasso/lorenz/results/lorenz_3_e4_e5_bo2000_se100_alasso_ridge_snr49.RData"
# [1] 1
# [1] 100
# [1] 2
# [1] 100
# [1] 3
# [1] 100
# [1] 4
# [1] 100
# [1] 5
